# %%
#importing the required packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn import linear_model
df=pd.read_csv(r"C:\Users\shery\Desktop\Housing_multiple_variant.csv")

# %%
display(df)
# Out:
#         price  lotsize  bedrooms  bathrms  stories  garagepl
# 0     42000.0     5850         3        1        2         1
# 1     38500.0     4000         2        1        1         0
# 2     49500.0     3060         3        1        1         0
# 3     60500.0     6650         3        1        2         0
# 4     61000.0     6360         2        1        1         0
# 5     66000.0     4160         3        1        1         0
# 6     66000.0     3880         3        2        2         2
# 7     69000.0     4160         3        1        3         0
# 8     83800.0     4800         3        1        1         0
# 9     88500.0     5500         3        2        4         1
# 10    90000.0     7200         3        2        1         3
# 11    30500.0     3000         2        1        1         0
# 12    27000.0     1700         3        1        2         0
# 13    36000.0     2880         3        1        1         0
# ...

# %%
yesno = {'yes': 1,'no': 0} 
  
# # traversing through dataframe 
# # yes and no column and writing 
# # values where key matches 
#df.driveway = [yesno[item] for item in df.driveway] 
#df.recroom = [yesno[item] for item in df.recroom] 
#df.fullbase = [yesno[item] for item in df.fullbase] 
#df.airco = [yesno[item] for item in df.airco] 
#df.gashw = [yesno[item] for item in df.gashw] 
print(df)
# Out:
#         price  lotsize  bedrooms  bathrms  stories  garagepl
# 0     42000.0     5850         3        1        2         1
# 1     38500.0     4000         2        1        1         0
# 2     49500.0     3060         3        1        1         0
# 3     60500.0     6650         3        1        2         0
# 4     61000.0     6360         2        1        1         0
# 5     66000.0     4160         3        1        1         0
# 6     66000.0     3880         3        2        2         2
# 7     69000.0     4160         3        1        3         0
# 8     83800.0     4800         3        1        1         0
# 9     88500.0     5500         3        2        4         1
# 10    90000.0     7200         3        2        1         3
# 11    30500.0     3000         2        1        1         0
# 12    27000.0     1700         3        1        2         0
# 13    36000.0     2880         3        1        1         0
# ...

# %%
from sklearn.model_selection import train_test_split
y=df.price
X=df.drop('price',axis=1)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
print("X_train:{}".format(X_train.shape))
print("X_test:{}".format(X_test.shape))
print("y_train:{}".format(y_train.shape))
print("y_test:{}".format(y_test.shape))
# Out:
# X_train:(382, 5)
# X_test:(164, 5)
# y_train:(382,)
# y_test:(164,)

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
x_new=[[4160,3,1,3,0]]
predic=reg.predict(x_new)
predic
# Out:
# array([63736.42202152])

# %%
y_pred=reg.predict(X_test)
#y_pred=y_pred.reshape(len(y_pred),1)
#y_test=y_test.reshape(len(y_test),1)

# %%
print("Test set score: {:.2f}".format(reg.score(X_test,y_test)))
# Out:
# Test set score: 0.53

# %%
#t=pd.DataFrame(y_pred)
#t

# %%
#a=np.array(y_test)
#b=np.array(y_pred)

#np.shape(b)
#a=a.reshape(len(b),1)
np.shape(X_test)
# Out:
# (164, 5)

# %%
plt.scatter(X_test['bedrooms'],y_test,  color='red')
plt.scatter(X_test['bedrooms'],y_pred, color='blue', linewidth=1)

#plt.xticks(())
#plt.yticks(())

plt.show()

# %%
X_test['lotsize']
# Out:
# 167    2800
# 178    3180
# 498    8250
# 53     4040
# 70     4095
# 367    7950
# 298    5450
# 218    3792
# 148    4800
# 252    6930
# 39     3150
# 326    8880
# 72     1836
# 82     3650
# 11     3000
# 304    5800
# 7      4160
# 472    9500
# 533    7686
# 55     3620
# 220    3120
# 76     1650
# 37     5170
# 263    4040
# 205    4000
# 455    3800
# 519    6000
# 8      4800
# 246    3480
# 255    3450
#        ...
# 259    6000
# 265    3640
# 80     4240
# 61     4750
# 166    3410
# 439    6862
# 543    6000
# 163    2135
# 369    6100
# 104    4992
# 267    3600
# 81     3240
# 411    6500
# 58     4400
# 322    8250
# 274    3640
# 14     3600
# 42     4640
# 52     9166
# 305    5885
# 142    4500
# 47     3090
# 407    6420
# 353    6800
# 286    7152
# 85     6480
# 32     4000
# 67     6000
# 264    3640
# 474    6670
# Name: lotsize, Length: 164, dtype: int64
